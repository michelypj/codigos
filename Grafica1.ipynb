# %%
import bz2
from numpy import*
from pylab import*
import matplotlib.pyplot as plt

dataeventos = loadtxt("datosarchivos.txt", float)

xlabel('Tiempo')
ylabel('Presión')
title('Presión en función del Tiempo') 
plt.plot( dataeventos[:,1] ,'o')
plt.savefig('presiontiempo.jpg')
plt.grid()
plt.show()
