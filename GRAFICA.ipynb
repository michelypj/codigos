# %%
import bz2
from numpy import*
from pylab import*
import matplotlib.pyplot as plt

dataeventos = loadtxt("datosarchivos.txt", float)

ylabel('Presión')
xlabel('Rate canal 3')
title('Presión como función del Rate') 
plt.plot( dataeventos[:,2], dataeventos[:,1],'o')
plt.savefig('presionrate.jpg')
plt.grid()
plt.show()
